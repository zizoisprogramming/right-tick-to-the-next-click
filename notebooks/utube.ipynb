# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.193.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Downloading httplib2-0.31.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.49.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.3.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.30.2-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.74.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting protobuf<8.0.0,>=4.25.8 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.27.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.5)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (43.0.3)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (1.16.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.2.2)
# Requirement already satisfied: pycparser in c:\users\asm el masrya\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.22)
# Downloading google_api_python_client-2.193.0-py3-none-any.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.9 MB 3.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/14.9 MB 3.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.8/14.9 MB 2.7 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/14.9 MB 2.9 MB/s eta 0:00:05
#    --------- ------------------------------ 3.7/14.9 MB 3.6 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/14.9 MB 3.6 MB/s eta 0:00:03
#    -------------- ------------------------- 5.2/14.9 MB 3.5 MB/s eta 0:00:03
#    --------------- ------------------------ 5.8/14.9 MB 3.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.0/14.9 MB 3.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.3/14.9 MB 3.0 MB/s eta 0:00:03
#    ------------------ --------------------- 6.8/14.9 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 7.1/14.9 MB 2.9 MB/s eta 0:00:03
#    ------------------- -------------------- 7.3/14.9 MB 2.8 MB/s eta 0:00:03
#    --------------------- ------------------ 7.9/14.9 MB 2.6 MB/s eta 0:00:03
#    --------------------- ------------------ 8.1/14.9 MB 2.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.4/14.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.7/14.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.7/14.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.7/14.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.9/14.9 MB 2.2 MB/s eta 0:00:03
#    ------------------------ --------------- 9.2/14.9 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 9.2/14.9 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.4/14.9 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 9.4/14.9 MB 1.9 MB/s eta 0:00:03
#    -------------------------- ------------- 9.7/14.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------- ------------- 9.7/14.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------- ------------- 10.0/14.9 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 10.2/14.9 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.5/14.9 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.7/14.9 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.7/14.9 MB 1.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.0/14.9 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 11.3/14.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 11.5/14.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 11.5/14.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 11.8/14.9 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.9 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.9 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.3/14.9 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.6/14.9 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.6/14.9 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.8/14.9 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.8/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.1/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.1/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/14.9 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/14.9 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------ --- 13.6/14.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/14.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/14.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.9 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.9 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.9 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/14.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.9 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 1.1 MB/s eta 0:00:00
# Downloading google_api_core-2.30.2-py3-none-any.whl (173 kB)
# Downloading google_auth-2.49.1-py3-none-any.whl (240 kB)
# Downloading google_auth_httplib2-0.3.1-py3-none-any.whl (9.5 kB)
# Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
# Downloading proto_plus-1.27.2-py3-none-any.whl (50 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, pyasn1, protobuf, httplib2, pyasn1-modules, proto-plus, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed google-api-core-2.30.2 google-api-python-client-2.193.0 google-auth-2.49.1 google-auth-httplib2-0.3.1 googleapis-common-protos-1.74.0 httplib2-0.31.2 proto-plus-1.27.2 protobuf-7.34.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 uritemplate-4.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.20 requires protobuf<5,>=4.25.3, but you have protobuf 7.34.1 which is incompatible.
# tensorflow-intel 2.16.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.0 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 7.34.1 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googleapiclient.discovery import build

api_key = "AIzaSyCdnwSmv06QyHVewZlOuApktFu-E5P4MTk"
youtube = build("youtube", "v3", developerKey=api_key)

request = youtube.search().list(
    part="snippet",
    q="tech",
    type="video",
    maxResults=50
)

response = request.execute()

video_ids = [item["id"]["videoId"] for item in response["items"]]
stats_request = youtube.videos().list(
    part="statistics,contentDetails,snippet",
    id=",".join(video_ids)
)

stats_response = stats_request.execute()

# %%
stats_response['items'][0]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'E0nj7zS5ZHov09YCnA9Suh4frG4',
#  'id': 's2OccJMWwkM',
#  'snippet': {'publishedAt': '2025-10-09T11:17:36Z',
#   'channelId': 'UCMiJRAwDNSNzuYeN2uWa0pA',
#   'title': 'REAL vs FAKE Tech',
#   'description': "The fakes were a LOT better than I expected \nGet the Insta360 GO Ultra: the best POV vlogging cam: https://bit.ly/Mrwhosetheboss-Insta360GOUltra. First 30 orders get an exclusive 256GB SD Card! \n- Tiny & Lightweight & Portable (just 53g)\n- Hands-Free POV + Wide FOV\n- Magic Magnetic Mounting\n- Upgraded Image: 1/1.28” Sensor + 5nm AI Chip\n- Long Battery Life: 60min @4K30 standalone; 170min @4K30 with Action Pod\n#Insta360GOUltra #pocketcamera #vloggingcamera\n\nI spend a LOT of time trying to make my videos as concise, polished and useful as possible for you - if you would like to support me on that mission then consider subscribing to the channel - you'd make my day 😁\n\nFor my tech hot takes: http://twitter.com/Mrwhosetheboss\nFor my Personal Posts: http://instagram.com/mrwhosetheboss\nFor quick tech videos: https://www.tiktok.com/@mrwhosetheboss\nDoes anyone still use this anymore?: https://facebook.com/mrwhosetheboss\n\nAmazon Affiliate links (if you buy anything through these it will support the channel and allow us to buy better gear!):\nAmazon US: https://amzn.to/3mFix9d\nAmazon UK: https://amzn.to/3GMPPtM\n\nMy Browser: https://opr.as/Opera-browser-Mr-Whose-the-Boss \nMy Filming Gear: https://bit.ly/35CuxwI\n\nMusic is from Epidemic sound:\nhttp://share.epidemicsound.com/pHDFT",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s2OccJMWwkM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/s2OccJMWwkM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/s2OccJMWwkM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/s2OccJMWwkM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/s2OccJMWwkM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'Mrwhosetheboss',
#   'tags': ['real',
#    'fake',
#    'tech',
#    'apple',
#    'philips hue',
#    'govee',
#    'gifts',
#    'gadgets'],
#   'categoryId': '28',
#   'liveBroadcastContent': 'none',
#   'defaultLanguage': 'en',
#   'localized': {'title': 'REAL vs FAKE Tech',
#    'description': "The fakes were a LOT better than I expected \nGet the Insta360 GO Ultra: the best POV vlogging cam: https://bit.ly/Mrwhosetheboss-Insta360GOUltra. First 30 orders get an exclusive 256GB SD Card! \n- Tiny & Lightweight & Portable (just 53g)\n- Hands-Free POV + Wide FOV\n- Magic Magnetic Mounting\n- Upgraded Image: 1/1.28” Sensor + 5nm AI Chip\n- Long Battery Life: 60min @4K30 standalone; 170min @4K30 with Action Pod\n#Insta360GOUltra #pocketcamera #vloggingcamera\n\nI spend a LOT of time trying to make my videos as concise, polished and useful as possible for you - if you would like to support me on that mission then consider subscribing to the channel - you'd make my day 😁\n\nFor my tech hot takes: http://twitter.com/Mrwhosetheboss\nFor my Personal Posts: http://instagram.com/mrwhosetheboss\nFor quick tech videos: https://www.tiktok.com/@mrwhosetheboss\nDoes anyone still use this anymore?: https://facebook.com/mrwhosetheboss\n\nAmazon Affiliate links (if you buy anything through these it will support the channel and allow us to buy better gear!):\nAmazon US: https://amzn.to/3mFix9d\nAmazon UK: https://amzn.to/3GMPPtM\n\nMy Browser: https://opr.as/Opera-browser-Mr-Whose-the-Boss \nMy Filming Gear: https://bit.ly/35CuxwI\n\nMusic is from Epidemic sound:\nhttp://share.epidemicsound.com/pHDFT"},
#   'defaultAudioLanguage': 'en-GB'},
#  'contentDetails': {'duration': 'PT22M46S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensedContent': True,
#   'contentRating': {},
#   'projection': 'rectangular'},
#  'statistics': {'viewCount': '12532806',
#   'likeCount': '223339',
#   'favoriteCount': '0',
#   'commentCount': '6127'}}

# %%
all_req = youtube.videos().list(
    part="snippet,statistics,contentDetails",
    fields=items(snippet(title,tags)),
    chart='mostPopular')

# %%
all_response = all_req.execute()

# %%
all_response['items'][0]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'OjEai_byViZbFjbUc6ENCI7CIrw',
#  'id': 'sDqEXirnuy4',
#  'snippet': {'publishedAt': '2026-04-03T16:01:19Z',
#   'channelId': 'UCq2QQO2WR5wz2IfLwt3SYfw',
#   'title': 'T.I. - Trauma Bond (Official Video)',
#   'description': 'Listen to the single “Trauma Bond". Out Now!\nStream: https://music.empi.re/traumabond\n\n \n\n#TI  #TraumaBond  #EMPIRE\n\n\nSubscribe on YouTube - https://bit.ly/TIPYouTube\n\nWatch T.I.\'s official music videos - https://bit.ly/TIMusicVideos\nexpediTIously full episodes - https://bit.ly/expediTIouslyEpisodes\nexpediTIously clips - https://bit.ly/expediTIouslyClips\n\n\n\n\nOfficial Lyric Video by T.I. - "Trauma Bond" © 2026 Grand Hustle LLC / EMPIRE',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sDqEXirnuy4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/sDqEXirnuy4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/sDqEXirnuy4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/sDqEXirnuy4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/sDqEXirnuy4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'TIVEVO',
#   'tags': ['T.I.', 'Grand Hustle LLC EMPIRE', 'Rap/Hip-Hop'],
#   'categoryId': '10',
#   'liveBroadcastContent': 'none',
#   'defaultLanguage': 'en',
#   'localized': {'title': 'T.I. - Trauma Bond (Official Video)',
#    'description': 'Listen to the single “Trauma Bond". Out Now!\nStream: https://music.empi.re/traumabond\n\n \n\n#TI  #TraumaBond  #EMPIRE\n\n\nSubscribe on YouTube - https://bit.ly/TIPYouTube\n\nWatch T.I.\'s official music videos - https://bit.ly/TIMusicVideos\nexpediTIously full episodes - https://bit.ly/expediTIouslyEpisodes\nexpediTIously clips - https://bit.ly/expediTIouslyClips\n\n\n\n\nOfficial Lyric Video by T.I. - "Trauma Bond" © 2026 Grand Hustle LLC / EMPIRE'},
#   'defaultAudioLanguage': 'en'},
#  'contentDetails': {'duration': 'PT3M41S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensedContent': True,
#   'regionRestriction': {'allowed': ['AD',
#     'AE',
#     'AF',
#     'AG',
#     'AI',
#     'AL',
#     'AM',
#     'AO',
#     'AQ',
#     'AR',
#     'AS',
#     'AT',
#     'AU',
#     'AW',
#     'AX',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BL',
#     'BM',
#     'BN',
#     'BO',
#     'BQ',
#     'BR',
#     'BS',
#     'BT',
#     'BV',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CC',
#     'CD',
#     'CF',
#     'CG',
#     'CH',
#     'CI',
#     'CK',
#     'CL',
#     'CM',
#     'CN',
#     'CO',
#     'CR',
#     'CU',
#     'CV',
#     'CW',
#     'CX',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'EH',
#     'ER',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FK',
#     'FM',
#     'FO',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GF',
#     'GG',
#     'GH',
#     'GI',
#     'GL',
#     'GM',
#     'GN',
#     'GP',
#     'GQ',
#     'GR',
#     'GS',
#     'GT',
#     'GU',
#     'GW',
#     'GY',
#     'HK',
#     'HM',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IM',
#     'IN',
#     'IO',
#     'IQ',
#     'IR',
#     'IS',
#     'IT',
#     'JE',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KP',
#     'KR',
#     'KW',
#     'KY',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MF',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MM',
#     'MN',
#     'MO',
#     'MP',
#     'MQ',
#     'MR',
#     'MS',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NC',
#     'NE',
#     'NF',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NU',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PF',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PM',
#     'PN',
#     'PR',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RE',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SD',
#     'SE',
#     'SG',
#     'SH',
#     'SI',
#     'SJ',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SO',
#     'SR',
#     'SS',
#     'ST',
#     'SV',
#     'SX',
#     'SY',
#     'SZ',
#     'TC',
#     'TD',
#     'TF',
#     'TG',
#     'TH',
#     'TJ',
#     'TK',
#     'TL',
#     'TM',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UM',
#     'US',
#     'UY',
#     'UZ',
#     'VA',
#     'VC',
#     'VE',
#     'VG',
#     'VI',
#     'VN',
#     'VU',
#     'WF',
#     'WS',
#     'YE',
#     'YT',
#     'ZA',
#     'ZM',
#     'ZW']},
#   'contentRating': {},
#   'projection': 'rectangular'},
#  'statistics': {'viewCount': '411544',
#   'likeCount': '34834',
#   'favoriteCount': '0',
#   'commentCount': '3208'}}
